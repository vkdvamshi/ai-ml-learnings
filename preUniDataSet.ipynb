# %%
import pandas as pd 
from PyPDF2 import PdfReader
from tabula import read_pdf
pd.set_option('display.max_columns', None) # Show all columns
pd.set_option('display.max_colwidth', None) # Don't truncate
pd.set_option('display.width', None)

# df = read_pdf("/Users/vkdvamshi/Downloads/10000_DirectInvoice_1080002220_2021-02-04.pdf", pages='all')[0]

reader = PdfReader("/Users/vkdvamshi/Downloads/10000_DirectInvoice_1080002220_2021-02-04.pdf")
page = reader.pages[0]
text = page.extract_text().encode('utf-8', 'ignore')
print(text)
# Out:
# b",QYRLFH \x06\x1d \x14\x13\x1b\x13\x13\x13\x15\x15\x15\x13LQYRLFH\n3DJH \x14 RI \x15&XVWRPHU \x06\x1d \x14\x13\x13\x13\x13\n,QYRLFH 'DWH\x1d \x13\x15\x12\x13\x17\x12\x15\x13\x15\x14%LOO 7R \x06\x1d \x14\x13\x13\x13\x13\n3XUFKDVH 2UGHU\x1d\n6HUYLFH /RFDWLRQ\x1d3D\\PHQW 7HUPV\x1d\n5RXWH \x06\x1d1HW\x16\x13\n\x16\x13 7,*$1 675((7\x0f :,1226.,\x0f 97 \x13\x18\x17\x13\x17\n$PRXQW 'XH\x1d\n&\x18\x1b\x1a\x13\x17\x18\x11\x19\x16 86'6+,3 72 %,// 727RWDO &XUUHQW &KDUJHV\x1d\n&XUUHQW &KDUJHV 'XH\x1d86' \x17\x18\x11\x19\x16\n\x13\x16\x12\x13\x19\x12\x15\x13\x15\x146,021\n6 (66(; &(17(5\n\x14\x16\x18 -(5,&+2 52$'\n(66(;\x0f 97 \x13\x18\x17\x18\x15\n6,021\n6 (66(; &(17(5\n\x14\x16\x18 -(5,&+2 52$'\n(66(;\x0f 97 \x13\x18\x17\x18\x153\x112\x11 %2; \x14\x16\x17\n3\x112\x11 %2; \x14\x16\x173D\\ E\\ 0DLO\x1d\n&RQWDFW 8QL)LUVW\x1d32 %2; \x19\x18\x13\x17\x1b\x14\n)RU &XVWRPHU 6HUYLFH FRQWDFW XV E\\\x1d\n3KRQH\x1d \x1b\x13\x13\x10\x1a\x1c\x17\x10\x15\x1a\x13\x19\n(PDLO\x1d &XVWRPHUVHUYLFH#XQLILUVW\x11FRP
# ...
