# %%
import pandas as pd 
from tabula import read_pdf
pd.set_option('display.max_columns', None) # Show all columns
pd.set_option('display.max_colwidth', None) # Don't truncate
pd.set_option('display.width', None)

df = pd.read_pdf("/Users/vkdvamshi/Downloads/10000_DirectInvoice_1080002220_2021-02-04.pdf", pages='all')

print ( df  )
# Out:
# [     LKR/ Unnamed: 0                                              Unnamed: 1  \
# 0     NaN       QTY.                                  DESCRIPTION OF SERVICE
# 1   DEPT.        NaN                                                     NaN
# 2     NaN         10                          APR-SPUNPOLY BIB NOPKT-BILL LI
# 3     NaN        NaN  APR-SPUNPOLY BIB NOPKT-BILL LI - Automatic Replacement
# 4     NaN          1                                     MAT-CP WET AREA 3X5
# 5     NaN          1                                   MAT-4X6 GREAT IMP 2.0
# 6     NaN          1                                  MAT-3X10 GREAT IMP 2.0
# 7     NaN          2                                  MAT-3X10 GREAT IMP 2.0
# 8     NaN          1                                  MOPS-HANDLE 1 1/8 X 60
# 9     NaN          1                                       MOPS-UNFRAMED 24"
# 10    NaN         60                                TERRY CLOTHS-U1ST BAGGED
# 11    NaN        NaN        TERRY CLOTHS-U1ST BAGGED - Automatic Replacement
# 12    NaN          1                                    LAUNDRY BAGS-SPECIAL
# 13    NaN          1                                             4X6H SIMONS
# 14    NaN        NaN                                       Linen Maintenance
# 15    NaN        NaN                                Invoice subtotal taxable
# 16    NaN        NaN                            Invoice subtotal non taxable
# 17    NaN        NaN                                         Total sales tax
# 18    NaN        NaN                                           Invoice Total
# 19    NaN        NaN                          Total Amount Due By 03/06/2021
#
#    Unnamed: 2 Unnamed: 3
# 0     Taxable     AMOUNT
# 1         NaN        NaN
# 2           N       2.30
# 3           N       0.53
# 4           Y       3.71
# 5           Y       3.71
# 6           Y       6.36
# 7           Y       8.48
# 8           Y       0.01
# 9           Y       0.80
# 10          Y      12.60
# 11          Y       0.82
# 12          Y       0.00
# 13          Y       1.06
# 14          N       3.00
# 15        NaN      37.55
# 16        NaN       5.83
# 17        NaN       2.25
# 18        NaN      45.63
# 19        NaN      45.63  ,       10                          APR-SPUNPOLY BIB NOPKT-BILL LI    N   2.30
# 0    NaN  APR-SPUNPOLY BIB NOPKT-BILL LI - Automatic Replacement    N   0.53
# 1    1.0                                     MAT-CP WET AREA 3X5    Y   3.71
# 2    1.0                                   MAT-4X6 GREAT IMP 2.0    Y   3.71
# 3    1.0                                  MAT-3X10 GREAT IMP 2.0    Y   6.36
# 4    2.0                                  MAT-3X10 GREAT IMP 2.0    Y   8.48
# 5    1.0                                  MOPS-HANDLE 1 1/8 X 60    Y   0.01
# 6    1.0                                       MOPS-UNFRAMED 24"    Y   0.80
# 7   60.0                                TERRY CLOTHS-U1ST BAGGED    Y  12.60
# 8    NaN        TERRY CLOTHS-U1ST BAGGED - Automatic Replacement    Y   0.82
# 9    1.0                                    LAUNDRY BAGS-SPECIAL    Y   0.00
# 10   1.0                                             4X6H SIMONS    Y   1.06
# 11   NaN                                       Linen Maintenance    N   3.00
# 12   NaN                                Invoice subtotal taxable  NaN  37.55
# 13   NaN                            Invoice subtotal non taxable  NaN   5.83
# 14   NaN                                         Total sales tax  NaN   2.25
# 15   NaN                                           Invoice Total  NaN  45.63
# 16   NaN                          Total Amount Due By 03/06/2021  NaN  45.63, Empty DataFrame
# Columns: [invoice, Customer #: Bill To #:, Unnamed: 0, 10000 10000, Unnamed: 1, Payment Terms: Route #:, Unnamed: 2, Net30C5870]
# Index: [],    Current  Over 30  Over 60  Over 90   Total     Bill To #:       10000  \
# 0   230.15      3.0    45.94      0.0  279.09  Invoice Date:  02/04/2021
#
#           Route #:  C5870
# 0  Purchase Order:    NaN  , Empty DataFrame
# Columns: [invoice, Customer #: Bill To #:, Unnamed: 0, 10000 10000, Unnamed: 1, Payment Terms: Route #:, Unnamed: 2, Net30C5870]
# Index: []]
