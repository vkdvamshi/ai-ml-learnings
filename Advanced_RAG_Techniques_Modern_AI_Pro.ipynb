# %% [markdown]
# #Modern AI Pro: Advanced RAG with LLMs
# The reasons why we need to use RAG:
# Problems that RAGs try to solve in LLMs
#
# 1. Hallucination — wrong generation with high confidence
# 2. Attribution — where does the information come from
# 3. Staleness — cut off date
# 4. Revisions — remove or revise information in the corpus
# 5. Customization — make it work in your own state
# 6. Low setup cost

# %% [markdown]
# ## Advanced RAG techniques
#
# 1. Multi-Query Generation - Generate 3-5 query variations, retrieve for all, deduplicate
# 2. Contextual Compression - Use LLM to extract only relevant parts from retrieved chunks
# 3. Parent Document Retrieval - Retrieve small chunks but return larger parent contexts
# 4. Self-RAG - Model checks if retrieval is needed and self-critiques responses
# 5. RAPTOR - Recursive clustering and summarization of documents into tree structure
# 6. Corrective RAG (CRAG) - Evaluates retrieval quality and falls back to web search if poor

# %% [markdown]
# ## Step 1: Load the data
# Building on top of this earlier [class](https://colab.research.google.com/drive/1BatABgfZpBdj1gIj6YVAs4ZuSOi2P9tr#scrollTo=Ejlt8qDLfoYV).

# %%
# !pip install -U -q langchain_groq google-genai pypdf2 langchain langchain-community sentence-transformers chromadb umap-learn tqdm
# !pip install requests==2.32.5
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 72.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 104.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 88.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 98.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 125.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.2/452.2 kB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Requirement already satisfied: requests==2.32.5 in /usr/local/lib/python3.12/dist-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5) (2025.8.3)

# %% [markdown]
# ## Step 1: Setup the basic knowledge management

# %% [markdown]
# ###1.1 LLM Setup

# %%
from google import genai, generativeai
from langchain_groq import ChatGroq
from google.colab import userdata

llm_groq = ChatGroq(model_name="llama-3.3-70b-versatile", api_key=userdata.get("GROQ_API_KEY"))

gemini_client = genai.Client(api_key=userdata.get("GEMINI_API-KEY"))

def llm_gemini(query, model_name="gemini-2.0-flash"):
  return gemini_client.models.generate_content(
    model=model_name, contents=query
).text
print(llm_gemini("write a haiku on RAG in AI in 3 lines"))
print(llm_gemini("write a haiku on Finetuning in AI in 3 lines", model_name="gemini-2.5-flash"))
# Out:
# Knowledge gaps it fills,
# Retrieves relevant answers,
# Context shines anew.
#
# Giant brain knows much,
# New facts shape its deep wisdom,
# Focused, sharp, it learns.

# %% [markdown]
# ### 1.2 Data download

# %%
import urllib.request
import PyPDF2
import io

franklin_10k = 'https://s201.q4cdn.com/562074409/files/doc_financials/2023/ar/Franklin-Resources-2023-Annual_10-K.pdf'
req = urllib.request.Request(franklin_10k, headers={'User-Agent' : "Magic Browser"})
remote_file = urllib.request.urlopen(req).read()
remote_file_bytes = io.BytesIO(remote_file)
reader = PyPDF2.PdfReader(remote_file_bytes)
pdf_texts = [p.extract_text().strip() for p in reader.pages]
pdf_texts = [text for text in pdf_texts if text]

# %%
# Utils:
def word_wrap(string, n_chars=128):
    # Wrap a string at the next space after n_chars
    if len(string) < n_chars:
        return string
    else:
        return string[:n_chars].rsplit(' ', 1)[0] + '\n' + word_wrap(string[len(string[:n_chars].rsplit(' ', 1)[0])+1:], n_chars)

word_wrap(pdf_texts[1])
# Out:
# 'f FRANKLIN RESOURCES, INC. ANNU AL REPORT 2023\nImportant Information Regarding Forward-Looking Statements and Non-GAAP\nFinancial Information\nThis report contains forward-looking statements that are provided under the “safe harbor” protection of\nthe Private Securities Litigation Reform Act of 1995  \nand involve a number of known and unknown risks, uncertainties and other\nimportant factors. You should read the discussions under the headings “Forward- \nLooking Statements” and “Risk Factors” in Part\nI of our Annual Report on Form 10-K for our fiscal year ended September 30, 2023 (“Form 10-K”) for important \ninformation\nconcerning such matters. This report also contains non-GAAP financial measures such as adjusted operating revenues, adjusted\noperating income, \nadjusted operating margin, adjusted net income and adjusted diluted earnings per share, which are not\nsubstitutes for measures calculated in accordance with \nU.S. GAAP. You should read the “Supplemental Non-GAAP Financial\nMeasures” section within Item 7 of our Form 10-K for, among other things, a presentation  \nof the most directly comparable\nmeasures calculated in accordance with U.S. GAAP and reconciliations from U.S. GAAP to non-GAAP.Part•ner•ship\nnoun: A\nrelationship of trust   \nand mut ual understanding in \n which all par ties are empowered \n to achieve together what they \n\ncould no t achieve alone.\nThe paper used in the printing of this annual report is manufactured with 100% Green-e Certified\nrenewable wind-generated electricity and contains at least 30% postconsumer waste recycled fiber. \nIn addition, the printer\nderives 100% of its electricity from Green-e Certified renewable wind energy sources.\n© 2023 Franklin Templeton. All rights\nreserved. Stock Transfer Agent, Registrar and  \nDividend Disbursing Agent \nComputershare \nP.O. Box 43078 \nProvidence, RI\n02940-3078\nOvernight correspondence \nComputershare \n150 Royall Street, Suite 101 \nCanton, MA 02021\nU.S. (866) 229-6632\n\nNon-U.S. (201) 680-65 78 \nTDD (800) 95 2-9245 \nNon-U.S. TDD (781) 575-4592 \nwww-us.computershare.com/investor\n\nwww-us.computershare.com/investor/contactThe common stock of Franklin Resources, Inc., \nis listed on the New York Stock\nExchange under \nthe ticker symbol BEN. For further information \nregarding the common stock or for a copy of our \nlatest Form\n10-K, including financial statements \nand financial statement schedules, free of charge, \nplease contact:Thomas C.\nMerchant\nExecutive Vice President  \nGeneral Counsel and Secretary \nFranklin Resources, Inc. \nOne Franklin Parkway \nSan Mateo,\nCA 94403-1906\nSelene Oh \nChief Communications Officer  \nand Head of Investor Relations \nFranklin Resources, Inc. \nOne Franklin\nParkway \nSan Mateo, CA 94403-1906 \n(650) 312-4091 \nInvestorRelations@franklintempleton.com\n\ninvestors.franklinresources.comLocal insights on a global scale\nWith more than 1,300 investment professionals based in over 25\ncountries around  \nthe world, we are uniquely positioned to identify up-and-coming opportunities  \nin local markets and assess\nthem from a global perspective.\nOur global footprint includes more than 9,000 employees in over 30 countries.\n FRANKLIN\nRESOURCES, INC. ANNU AL REPORT 2023  1\nImportant Information Regarding Forward-Looking Statements and Non-GAAP Financial\nInformation\nThis report contains forward-looking statements that are provided under the “safe harbor” protection of the Private\nSecurities Litigation Reform Act of 1995  \nand involve a number of known and unknown risks, uncertainties and other important\nfactors. You should read the discussions under the headings “Forward-  \nLooking Statements” and “Risk Factors” in Part I of our\nAnnual Report on Form 10-K for our fiscal year ended September 30, 2023 (“Form 10-K”) for important \ninformation concerning\nsuch matters. This report also contains non-GAAP financial measures such as adjusted operating revenues, adjusted operating\ni ...

# %% [markdown]
# ###1.3 Split the texts

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, SentenceTransformersTokenTextSplitter
character_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=50,
    length_function=len,
    add_start_index=True,
)
character_split_texts = []
chunk_metadata = []

for page_num, page_text in enumerate(pdf_texts):
    page_chunks = character_splitter.split_text(page_text)
    for chunk in page_chunks:
        character_split_texts.append(chunk)
        chunk_metadata.append({'page': page_num + 1, 'source': 'Franklin 10K'})

print(f"Total chunks with page info: {len(character_split_texts)}")
print(f"Sample metadata: {chunk_metadata[10]}")
# Out:
# Total chunks with page info: 517
# Sample metadata: {'page': 2, 'source': 'Franklin 10K'}

# %%
import chromadb
from chromadb.utils.embedding_functions import SentenceTransformerEmbeddingFunction

embedding_function = SentenceTransformerEmbeddingFunction()

chroma_client = chromadb.Client()
chroma_collection = chroma_client.create_collection("ft_vector", embedding_function=embedding_function)

ids = [str(i) for i in range(len(character_split_texts))]

chroma_collection.add(
    ids=ids,
    documents=character_split_texts,
    metadatas=chunk_metadata
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
results = chroma_collection.query(
    query_texts=["What is Franklin Templeton's revenue?"],
    n_results=3,
    include=['documents', 'metadatas']
)

for i, (doc, meta) in enumerate(zip(results['documents'][0], results['metadatas'][0])):
    print(f"Result {i+1} (Page {meta['page']}):")
    print(doc[:200] + "...\n")
# Out:
# Result 1 (Page 4):
# support the investment management lifecycle.
# This effort will allow us to address the needs
# of our specialist investment managers and
# better position us to scale for future growth.
# This year, we a...
#
# Result 2 (Page 3):
# accurate, complete or timely. Neither Morningstar nor its content providers are responsible for any damages or losses arising from any use of this information.
#  FRANKLIN RESOURCES, INC. ANNU AL REPORT...
#
# Result 3 (Page 4):
# contribution where combined we will have
# over $100 billion in AUM. Furthermore, the
# acquisition is structured to maintain Franklin
# Templeton’s financial flexibility and promote Matthew Nicholls
# Exe...

# %% [markdown]
# ## Step 2: Visualize the query.

# %% [markdown]
# ### 2.1 Setup UMAP transformation

# %%
import umap
from tqdm import tqdm
import numpy as np
embeddings = chroma_collection.get(include=['embeddings'])['embeddings']
umap_transform = umap.UMAP(random_state=0, transform_seed=0).fit(embeddings)
umap_embeddings = umap_transform.transform(embeddings)
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# ### 2.2 Plot the projections

# %%
import matplotlib.pyplot as plt

def visualize_results(query, projected_query_embedding, projected_retrieved_embeddings):
    plt.figure(figsize=(8, 6))
    plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], s=10, color='gray', alpha=0.5)
    plt.scatter(projected_query_embedding[:, 0], projected_query_embedding[:, 1], s=150, marker='X', color='red', label='Query')
    plt.scatter(projected_retrieved_embeddings[:, 0], projected_retrieved_embeddings[:, 1], s=100, facecolors='none', edgecolors='green', label='Retrieved')

    plt.legend()
    plt.title(query)
    plt.axis('off')
    plt.tight_layout()

# %%
def visualize_query(query):
    results = chroma_collection.query(query_texts=[query], n_results=5, include=['documents', 'embeddings'])

    for document in results['documents'][0]:
        print(document[:200] + "...\n")  # Simple truncation instead of word_wrap

    projected_retrieved_embeddings = umap_transform.transform(results['embeddings'][0])
    query_embedding = embedding_function([query])
    projected_query_embedding = umap_transform.transform(query_embedding)

    visualize_results(query, projected_query_embedding, projected_retrieved_embeddings)

# %%
query = "key revenue drivers"
visualize_query(query)
# Out:
# continued contributions of these people. Global and/or local laws and regulations could impose restrictions on
# compensation paid by financial institutions, which could restrict our ability to compete...
#
# subsidiaries are determined using discounted cash flows and guideline public company methods, which include significant
# assumptions about forecasts of the AUM growth rate, pre-tax profit margin, disc...
#
# Other      . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  40.1  50.5  37.2
# Total operating revenues       . . . . . . . . . . ....
#
# regions, or our inability to recover successfully following a disaster or other business continuity problem, could adversely
# impact our business and operations.
# HUMAN CAPITAL RISKS
# We depend on key p...
#
# declines, credit or interest rate volatility or uncertainty, increased redemptions or other factors could negatively impact our
# revenues and income.
# INVESTMENT PERFORMANCE AND REPUTATIONAL RISKS
# Poor...

# %% [markdown]
# ## Step 3: Query Intelligence

# %% [markdown]
# ### 3.1 Query analysis

# %%
import re
import json
def analyze_query(query):
        """Step 1: Basic query analysis and classification"""

        analysis_prompt = f"""
        Analyze this query and provide a JSON response with these classifications:

        Query: "{query}"

        Respond with JSON with nothing else so that it can be parsed:
        {{
            "needs_retrieval": true/false,
            "query_type": "factual/analytical/comparison/conversational",
            "domain": "financial/general/technical/other",
            "complexity": "simple/moderate/complex",
            "reasoning": "brief explanation of classification"
        }}

        Guidelines:
        - needs_retrieval: false for basic knowledge (What does NPV mean?, math calculations),
           true only for items that require proprietary info from internal sources
        - factual: looking up specific facts
        - analytical: requires analysis of data
        - comparison: comparing multiple things
        - conversational: greetings, follow-ups
        - unrelated: queries unrelated to financial performance at Franklin Templeton
        """

        response = llm_gemini(analysis_prompt)
        json_text = re.search(r'```json\n(.*?)\n```', response, re.DOTALL).group(1)
        parsed_json = json.loads(json_text)

        return parsed_json

# %%
analyze_query("what is an IRR?")
# Out:
# {'needs_retrieval': False,
#  'query_type': 'factual',
#  'domain': 'financial',
#  'complexity': 'simple',
#  'reasoning': 'The query asks for the definition of a common financial term (IRR), which can be answered with general knowledge. No proprietary data is needed.'}

# %%
analyze_query("Explain key revenue drivers in Franklin Templeton")
# Out:
# {'needs_retrieval': True,
#  'query_type': 'analytical',
#  'domain': 'financial',
#  'complexity': 'moderate',
#  'reasoning': "Requires understanding and analysis of Franklin Templeton's specific business operations to identify key revenue drivers. This information is likely proprietary and not readily available, hence requiring retrieval. It is an analytical question since it involves more than just stating facts, but also interpreting their relationship to revenue."}

# %% [markdown]
# ### 3.2 Hypothetical embeddings

# %%
def generate_hyde(query):
        """Generate hypothetical document for HyDE technique"""
        hyde_prompt = f"""
        Generate a hypothetical answer to this question as if it came from a financial document.
        Keep it factual and specific. Focus on the type of information that would answer the query.

        Query: {query}

        Hypothetical answer:
        """
        return llm_gemini(hyde_prompt)
generate_hyde("Which growth strategies are important for Franklin Templeton in 2023")
# Out:
# '**Franklin Templeton - Growth Strategies for Fiscal Year 2023**\n\nThis section outlines key strategic initiatives undertaken in Fiscal Year 2023 aimed at driving organic and inorganic growth. Our strategies are focused on leveraging existing strengths, expanding into high-growth markets, and enhancing our competitive position.\n\n*   **Organic Growth Initiatives:**\n\n    *   **Product Innovation and Diversification:** We are focused on launching and expanding our Exchange Traded Fund (ETF) offerings, particularly in thematic and active strategies. This includes the launch of [Number] new ETFs focused on [Specific Sector/Theme 1] and [Specific Sector/Theme 2], with projected AUM growth of [Specific Percentage] within the first year. Additionally, we are prioritizing the development of customized investment solutions for institutional clients.\n    *   **Geographic Expansion:** Expansion into high-growth markets, specifically [Specific Emerging Market Region/Country 1] and [Specific Emerging Market Region/Country 2], remains a priority. This includes establishing strategic partnerships with local distributors and developing products tailored to the specific needs of these markets. Projected AUM growth from these regions is estimated at [Specific Percentage] over the next [Number] years.\n    *   **Enhanced Distribution Capabilities:** We are investing in technology and personnel to enhance our distribution network. This includes implementing a new CRM system to improve client relationship management and expanding our sales team in [Specific Geographic Region]. We are also focusing on strengthening our relationships with key financial advisors through targeted marketing campaigns and educational programs.\n\n*   **Inorganic Growth Initiatives:**\n\n    *   **Strategic Acquisitions:** We are actively evaluating potential acquisition targets that align with our strategic priorities, particularly in the areas of [Specific Asset Class/Investment Style 1] and [Specific Asset Class/Investment Style 2]. We aim to acquire firms with differentiated investment capabilities and strong track records. The budget allocated for potential acquisitions in FY23 is [Specific Dollar Amount].\n    *   **Strategic Partnerships and Joint Ventures:** We continue to explore strategic partnerships and joint ventures to expand our product offerings and geographic reach. In Q[Specific Quarter], we entered into a joint venture with [Specific Company Name] to develop and distribute [Specific Product Type] in [Specific Geographic Region].\n\n**Key Performance Indicators (KPIs):**\n\n*   Organic AUM Growth Rate: Target of [Specific Percentage] for FY23.\n*   New ETF AUM: Target of [Specific Dollar Amount] for FY23.\n*   Client Retention Rate: Target of [Specific Percentage] for FY23.\n*   Acquisition Integration Success Rate: Measured by [Specific Metric] within [Number] months of acquisition completion.\n\nThese strategies are subject to market conditions and various risks, as outlined in the "Risk Factors" section of this document. We believe that these initiatives will position Franklin Templeton for continued growth and success in the evolving investment landscape.\n'

# %% [markdown]
# ### 3.3 Multiqueries

# %%
def generate_multi_queries(query):
        """Generate multiple related queries for comprehensive search"""
        multi_query_prompt = f"""
        Break this comparison query into 2-3 focused sub-queries that will help gather comprehensive information.

        Original query: {query}

        Provide 2-3 specific sub-queries, one per line:
        """

        response = llm_gemini(multi_query_prompt)
        queries = [q.strip() for q in response.strip().split('\n') if q.strip()]
        return queries[:3]
generate_multi_queries("Explain the key revenue drivers at Franklin Templeton")
# Out:
# ["1.  What are Franklin Templeton's primary sources of assets under management (AUM) and how has AUM changed over the last 5 years?",
#  '2.  What are the different types of investment products and services that Franklin Templeton offers and their associated fee structures?',
#  "3.  How do market performance and investor behavior (e.g., inflows/outflows) impact Franklin Templeton's revenue?"]

# %% [markdown]
# ### 3.4 Route and Enhance

# %%
def route_query(query):
    analysis = analyze_query(query)

    if not analysis["needs_retrieval"]:
        return "direct_answer"
    elif analysis["query_type"] == "analytical":
        return "hyde_retrieval"
    elif analysis["query_type"] == "comparison":
        return "multi_query"
    else:
        return "simple_retrieval"

route_query("Explain the key revenue drivers at Franklin Templeton")
# Out:
# 'hyde_retrieval'

# %%
def enhance_query(query):
    strategy = route_query(query)

    if strategy == "hyde_retrieval":
        hyde_doc = generate_hyde(query)
        return [f"{query} {hyde_doc}"]
    elif strategy == "multi_query":
        return generate_multi_queries(query)
    else:
        return [query]

enhance_query("Explain the key revenue drivers at Franklin Templeton")
# Out:
# ["Explain the key revenue drivers at Franklin Templeton **Revenue Driver Analysis: Franklin Templeton (FT)**\n\nFT's revenue is primarily driven by assets under management (AUM) and the fees generated from managing those assets. Key revenue drivers and their contributions are outlined below:\n\n*   **Investment Management Fees (IMF):** The most significant revenue driver, IMF represented approximately 85% of total revenue in Fiscal Year 2023 (ending September 30, 2023). IMF is calculated as a percentage of AUM. Fluctuations in AUM, performance-based fees, and changes in fee rates directly impact IMF.\n    *   **AUM Growth:** Organic AUM growth, driven by net inflows into FT investment products and positive market performance, is a critical factor. A 1% increase in AUM, assuming constant fee rates, is projected to increase IMF by approximately $45 million based on FY23 AUM and average fee rates.\n    *   **Product Mix:** The mix of AUM across different asset classes (e.g., equity, fixed income, multi-asset, alternative investments) significantly influences IMF. Higher-yielding asset classes, such as alternative investments, command higher fee rates, contributing disproportionately to IMF. The current AUM allocation is roughly 40% in Equity, 35% in Fixed Income, 15% in Alternatives, and 10% in Multi-Asset.\n    *   **Fee Rates:** Average fee rates vary across asset classes and investment strategies. Competitive pressures and client mandates influence fee rate structures. A 1 basis point (0.01%) change in the average fee rate across all AUM would impact IMF by approximately $4.5 million, based on FY23 AUM.\n*   **Distribution Fees:** Revenue generated from providing distribution and shareholder services to investment products. Distribution fees constitute approximately 10% of total revenue. Growth in distribution revenue is closely tied to AUM in products that levy distribution fees.\n*   **Other Revenue:** Includes transfer agent fees, securities lending revenue, and other ancillary services. Other revenue accounts for approximately 5% of total revenue.\n*   **Foreign Exchange (FX) Impact:** As a global asset manager, FT's revenue is subject to FX fluctuations. A strengthening US dollar typically has a negative impact on reported revenue when translating revenue from foreign currencies. FY23 revenues were negatively impacted by approximately $50 million due to unfavorable FX rates.\n"]

# %% [markdown]
# ### 3.5 Putting it all together

# %%
def intelligent_retrieval(query):
    """Route query and retrieve documents intelligently"""

    enhanced_queries = enhance_query(query)
    strategy = route_query(query)

    print(f"Strategy: {strategy}")
    print(f"Enhanced queries: {enhanced_queries}")

    # Route based on strategy
    if strategy == "direct_answer":
        response = llm_gemini(query)
        return {
            "answer": response,
            "method": strategy,
            "documents_used": 0
        }

    elif strategy in ["simple_retrieval", "hyde_retrieval"]:
        # Single query retrieval
        results = chroma_collection.query(
            query_texts=enhanced_queries,
            n_results=5
        )
        documents = results['documents'][0]

    elif strategy == "multi_query":
        # Multiple queries - pool all results
        all_documents = []
        for q in enhanced_queries:
            print(f"  Searching: {q}")
            results = chroma_collection.query(query_texts=[q], n_results=3)
            all_documents.extend(results['documents'][0])

        # Remove duplicates while preserving order
        documents = list(dict.fromkeys(all_documents))

    # Generate answer with context
    context = "\n\n".join(documents)
    prompt = f"Question: {query}\n\nContext: {context}\n\nAnswer based on the context:"
    response = llm_gemini(prompt, model_name="gemini-2.5-flash-lite")

    return {
        "answer": response,
        "method": strategy,
        "documents_used": len(documents),
        "context_preview": context[:200] + "..."
    }
intelligent_retrieval("Explain the key revenue drivers at Franklin Templeton")
# Out:
# Strategy: hyde_retrieval
# Enhanced queries: ["Explain the key revenue drivers at Franklin Templeton ## Franklin Templeton - Revenue Driver Analysis\n\n**Revenue Generation:** Franklin Templeton's revenue is primarily derived from investment management fees charged on assets under management (AUM). These fees are typically calculated as a percentage of AUM, varying depending on the investment strategy, asset class, and client type. Consequently, the key drivers of revenue are:\n\n**1. Average Assets Under Management (AUM):**\n\n*   **Market Performance:** Positive market performance, across equity, fixed income, and alternative asset classes, directly increases AUM through capital appreciation. Conversely, negative market performance reduces AUM.\n*   **Net Flows:** Net inflows (client deposits exceeding withdrawals) increase AUM, while net outflows decrease AUM. Net flows are influenced by investment performance relative to benchmarks and competitors, sales efforts, and client preferences.\n*   **Acquisitions & Divestitures:** Strategic acquisitions of other asset managers or the launch of new investment strategies organically contribute to AUM. Divestitures, while less frequent, conversely reduce AUM. AUM figures are disclosed quarterly in the company's 10-Q and annually in the 10-K filings, segmented by asset class and investment strategy.\n\n**2. Fee Rate (Basis Points):**\n\n*   **Asset Mix:** The mix of AUM across different asset classes and investment strategies significantly impacts the overall fee rate. Higher-fee asset classes, such as alternative investments (private equity, hedge funds) and specialized equity strategies, contribute proportionally more to revenue than lower-fee asset classes like passive fixed income.\n*   **Client Type:** Institutional clients often negotiate lower fee rates compared to retail clients due to the size of their investments. The proportion of AUM managed for institutional versus retail clients influences the overall fee rate.\n*   **Fee Pressure:** Competitive pressures within the asset management industry can lead to fee compression, particularly in passively managed strategies. This can negatively impact the overall fee rate realized on AUM. Analysis of fee rates charged by investment type can be found in the supplementary data in our annual 10-K report.\n\n**3. Other Revenue:**\n\n*   While investment management fees constitute the majority of revenue, other revenue sources include:\n    *   **Distribution Fees:** Charged on specific fund products, primarily in retail channels.\n    *   **Transfer Agent Fees:** Fees collected for administrative services related to fund shareholder accounts.\n    *   **Other Service Fees:** Revenue generated from providing specific investment-related services to clients. These revenue streams represent a smaller percentage of total revenue compared to investment management fees.\n\n**Key Performance Indicators (KPIs):**\n\nManagement closely monitors the following KPIs to assess and manage revenue drivers:\n\n*   **AUM by Asset Class & Geography**\n*   **Net Flow Rates**\n*   **Average Fee Rate (Overall and by Asset Class)**\n*   **Client Retention Rate**\n*   **Sales Productivity**\n\nDetailed performance data related to these KPIs is discussed in our quarterly earnings calls and presented in the associated earnings release.\n"]
# {'answer': "Based on the provided context, Franklin Templeton's key revenue drivers are:\n\n*   **Assets Under Management (AUM) and their relative mix:** This is explicitly stated as the primary determinant of their revenues. The higher the AUM and the more favorable the mix (towards higher-fee products), the higher their revenue. Fluctuations in AUM due to market volatility, asset outflows, or declining security prices negatively impact revenues.\n*   **Fees Charged for Services:** The level of revenues also depends on the fees Franklin Templeton charges for its services, which are determined by contracts with funds and customers. These fees are structured in several ways:\n    *   **Investment Management Fees:** These are generally calculated as a percentage of AUM, typically on a monthly basis using daily average AUM. They are recognized as services are provided.\n    *   **Performance-Based Investment Management Fees:** These are generated when the performance of investment products exceeds specific targets outlined in customer contracts. These fees are recognized when it's no longer probable that the amount will be reversed.\n    *   **Sales and Distribution Fees:** These primarily include upfront sales commissions and ongoing distribution fees. Sales commissions are based on contractual rates for the sale of certain fund classes and are recognized on the trade date.\n*   **Sub-Advisory Services:** Franklin Templeton also earns revenue by providing sub-advisory services to investment products sponsored by other companies.",
#  'method': 'hyde_retrieval',
#  'documents_used': 5,
#  'context_preview': 'Investment Partners, Templeton® and Western Asset Management Company®. We offer a broad product mix of fixed \nincome, equity, alternative, multi-asset and cash management asset classes and solutions t...'}

# %%
def simple_multistep_rag(query):
    # Step 1: Better prompt for multiple questions
    prompt = f"""Break this into exactly 3 questions. Format as:
1. [question 1]?
2. [question 2]?
3. [question 3]?

Original: {query}"""

    response = llm_gemini(prompt)
    print(f"Sub questions: {response}")

    # Extract questions
    sub_questions = []
    for line in response.split('\n'):
        if re.match(r'^\d+\.', line.strip()):
            question = re.sub(r'^\d+\.\s*', '', line.strip())
            if question and '?' in question:
                sub_questions.append(question)

    # Step 2: Answer each sub-question (OUTSIDE the print loop)
    answers = [intelligent_retrieval_with_citations(q)['answer'] for q in sub_questions]

    # Step 3: Combine answers
    final_answer = llm_gemini(f"Using these answers, respond to '{query}': {answers}")
    return final_answer

simple_multistep_rag("What growth strategies does Franklin Templeton use ")
# Out:
# Sub questions: Here are three questions based on the original:
#
# 1. What are the primary growth strategies employed by Franklin Templeton?
# 2. Can you describe specific examples of how Franklin Templeton implements these growth strategies?
# 3. How effective have Franklin Templeton's growth strategies been in terms of market share, assets under management, and overall profitability?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-327647570.py in <cell line: 0>()
#      26     return final_answer
#      27
# ---> 28 simple_multistep_rag("What growth strategies does Franklin Templeton use ")
#
# /tmp/ipython-input-327647570.py in simple_multistep_rag(query)
#      20
#      21     # Step 2: Answer each sub-question (OUTSIDE the print loop)
# ---> 22     answers = [intelligent_retrieval_with_citations(q)['answer'] for q in sub_questions]
#      23
#      24     # Step 3: Combine answers
#
# NameError: name 'intelligent_retrieval_with_citations' is not defined

# %%
def visualize_all_enhancements_with_docs(query):
    """Visualize query enhancements with retrieved document context"""

    # Generate all enhancement types
    hyde_query = generate_hyde(query)
    multi_queries = generate_multi_queries(query)

    # Get embeddings for queries
    original_embedding = embedding_function([query])
    hyde_embedding = embedding_function([f"{query} {hyde_query}"])
    multi_embeddings = embedding_function(multi_queries)

    # Project queries to 2D
    projected_original = umap_transform.transform(original_embedding)
    projected_hyde = umap_transform.transform(hyde_embedding)
    projected_multi = umap_transform.transform(multi_embeddings)

    # Get retrieved documents for each strategy
    original_results = chroma_collection.query(query_texts=[query], n_results=5, include=['embeddings'])
    hyde_results = chroma_collection.query(query_texts=[f"{query} {hyde_query}"], n_results=5, include=['embeddings'])

    # Project retrieved docs
    projected_original_docs = umap_transform.transform(original_results['embeddings'][0])
    projected_hyde_docs = umap_transform.transform(hyde_results['embeddings'][0])

    # Plot
    plt.figure(figsize=(14, 10))

    # Background: all documents
    plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], s=8, color='gray', alpha=0.8, label='All documents', zorder=1)

    plt.scatter(projected_original_docs[:, 0], projected_original_docs[:, 1], s=60, facecolors='none', edgecolors='red', linewidth=2, label='Original retrieval', zorder=3)
    plt.scatter(projected_hyde_docs[:, 0], projected_hyde_docs[:, 1], s=60, facecolors='none', edgecolors='orange', linewidth=2, label='HyDE retrieval', zorder=3)
    plt.scatter(projected_original[:, 0], projected_original[:, 1], s=300, marker='X', color='red', label='Original query', edgecolors='black', linewidth=2, zorder=4)

    # Retrieved documents by strategy
    plt.scatter(projected_original_docs[:, 0], projected_original_docs[:, 1], s=60, facecolors='none', edgecolors='red', linewidth=2, label='Original retrieval')
    plt.scatter(projected_hyde_docs[:, 0], projected_hyde_docs[:, 1], s=60, facecolors='none', edgecolors='orange', linewidth=2, label='HyDE retrieval')

    # Query points
    plt.scatter(projected_original[:, 0], projected_original[:, 1], s=300, marker='X', color='red', label='Original query', edgecolors='black', linewidth=2)
    plt.scatter(projected_hyde[:, 0], projected_hyde[:, 1], s=250, marker='s', color='orange', label='HyDE enhanced', edgecolors='black')
    plt.scatter(projected_multi[:, 0], projected_multi[:, 1], s=200, marker='o', color='blue', label='Multi-queries', edgecolors='black')

    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.title(f'Query Enhancement with Document Context\n"{query}"')
    plt.axis('off')
    plt.tight_layout()

# Test
visualize_all_enhancements_with_docs("key revenue drivers")

# %% [markdown]
# ## Step 4: Bringing citations and references

# %%
def generate_answer_with_citations(query, documents, metadata):
    """Generate answer with inline citations"""

    # Create numbered context with metadata
    context_with_numbers = ""
    for i, (doc, meta) in enumerate(zip(documents, metadata)):
        context_with_numbers += f"[{i+1}] (Page {meta['page']}) {doc}\n\n"

    prompt = f"""Question: {query}

Context with source numbers:
{context_with_numbers}

Answer the question and include [number] citations inline when referencing specific information from the sources. Only cite when making specific claims from the documents.

Answer:"""

    return llm_gemini(prompt)

def intelligent_retrieval_with_citations(query):
    """Enhanced retrieval with proper citations"""

    enhanced_queries = enhance_query(query)
    strategy = route_query(query)

    if strategy == "direct_answer":
        return {"answer": llm_gemini(query), "method": strategy}

    # Get documents with metadata
    results = chroma_collection.query(
        query_texts=enhanced_queries,
        n_results=5,
        include=['documents', 'metadatas']
    )

    documents = results['documents'][0]
    metadata = results['metadatas'][0]

    cited_answer = generate_answer_with_citations(query, documents, metadata)

    references = "\n\nReferences:\n"
    for i, meta in enumerate(metadata):
        references += f"[{i+1}] Franklin 10K, Page {meta['page']}\n"

    return {"answer": cited_answer + references, "method": strategy}

# Test with citations
query = "Who are Franklin Templeton's key executives?"
result = intelligent_retrieval_with_citations(query)
print(result["answer"])
# Out:
# Based on the provided documents, here are some of Franklin Templeton's key executives:
#
# *   **Jennifer M. Johnson:** President and Chief Executive Officer of Franklin Resources, Inc. [4]
# *   **Matthew Nicholls:** Executive Vice President and Chief Financial Officer [2]
# *   **Selene Oh:** Chief Communications Officer [3]
# *   **Jennifer Ball:** Chief Marketing Officer [3]
# *   **Adam Petryk, CFA:** Head of Franklin Templeton Investment Solutions [3]
# *   **Brett Goldstein, CFA:** Co-Chief Investment Officer, Putnam Global Asset Allocation [3]
# *   **Wylie Tollette, CFA:** Chief Investment Officer, Franklin Templeton Investment Solutions [3]
# *   **Robert Schoen:** Co-Chief Investment Officer, Putnam Global Asset Allocation [3]
#
#
# References:
# [1] Franklin 10K, Page 4
# [2] Franklin 10K, Page 4
# [3] Franklin 10K, Page 5
# [4] Franklin 10K, Page 3
# [5] Franklin 10K, Page 7

# %% [markdown]
# ## Step 5. Evaluation and Scoring

# %% [markdown]
# ### 5.1 LLM as a Judge

# %%
def evaluate_answer_quality(query, answer, context):
    """Comprehensive answer evaluation with reasoning"""

    prompt = f"""
    Evaluate this RAG system response and respond with ONLY valid JSON:

    Query: {query}
    Answer: {answer}
    Context: {context[:800]}...

    {{
        "relevance_score": 1-5,
        "accuracy_score": 1-5,
        "completeness_score": 1-5,
        "citation_quality": 1-5,
        "reasoning": "brief explanation"
    }}
    """

    response = llm_gemini(prompt).strip()

    try:
        # Try to extract JSON from response
        import re
        json_match = re.search(r'\{.*\}', response, re.DOTALL)
        if json_match:
            result = json.loads(json_match.group())
        else:
            result = json.loads(response)
        return result
    except Exception as e:
        print(f"JSON Parse Error: {e}")
        print(f"Raw response: {response}")
        return {
            "relevance_score": 3,
            "accuracy_score": 3,
            "completeness_score": 3,
            "citation_quality": 3,
            "reasoning": f"Parse failed: {response[:100]}"
        }

# %%
def evaluate_retrieval_quality(query, retrieved_docs):
    """Evaluate if retrieved documents are relevant to query"""

    relevant_count = 0
    for doc in retrieved_docs[:3]:  # Check top 3
        prompt = f"Does this document help answer '{query}'? Yes/No: {doc[:200]}..."
        response = llm_gemini(prompt).lower()
        if 'yes' in response:
            relevant_count += 1

    return relevant_count / len(retrieved_docs[:3])  # Precision@3

def evaluate_rag_system(query):
    """Evaluate the complete RAG pipeline"""

    # Get answer and context from our system
    result = intelligent_retrieval_with_citations(query)
    answer = result["answer"]
    method = result["method"]

    if method == "direct_answer":
        print(f"Query: {query}")
        print(f"Method: {method}")
        print("No retrieval performed - direct LLM answer")
        print("-" * 50)
        return

    # Get context for evaluation
    enhanced_queries = enhance_query(query)
    results = chroma_collection.query(
        query_texts=enhanced_queries,
        n_results=5,
        include=['documents']
    )
    context = "\n".join(results['documents'][0])

    # Evaluate
    evaluation = evaluate_answer_quality(query, answer, context)

    print(f"Query: {query}")
    print(f"Method: {method}")
    print(f"Relevance: {evaluation['relevance_score']}/5")
    print(f"Accuracy: {evaluation['accuracy_score']}/5")
    print(f"Completeness: {evaluation['completeness_score']}/5")
    print(f"Citation Quality: {evaluation['citation_quality']}/5")
    print(f"Reasoning: {evaluation['reasoning']}")
    print("-" * 50)

    return evaluation

# %%
test_queries = [
    "Who are Franklin Templeton's key executives?",  # Should work well - factual
    "How does Franklin Templeton's business model generate revenue?",  # Analytical - should trigger HyDE
    "Compare Franklin Templeton's 2023 performance vs previous years",  # Comparison - should trigger multi-query
    "What is the outlook for Franklin Templeton's growth strategy?",  # Complex analytical
    "What does NPV mean in finance?",  # General knowledge - should get direct answer
    "Franklin Templeton's biggest risks and challenges",  # Should find risk disclosures
    "How many employees does Franklin Templeton have worldwide?"  # Specific fact that may/may not be in doc
]

for query in test_queries:
    print(f"\n{'='*60}")
    evaluate_rag_system(query)
# Out:
# ============================================================
# Query: Who are Franklin Templeton's key executives?
# Method: simple_retrieval
# Relevance: 5/5
# Accuracy: 5/5
# Completeness: 4/5
# Citation Quality: 5/5
# Reasoning: The response directly answers the question. The named executives are listed along with their titles. The response is drawn from the document, and the citations are specific. The answer is mostly complete but might be more exhaustive with a larger set of documents.
# --------------------------------------------------
#
# ============================================================
# Query: How does Franklin Templeton's business model generate revenue?
# Method: simple_retrieval
# Relevance: 5/5
# Accuracy: 5/5
# Completeness: 4/5
# Citation Quality: 5/5
# Reasoning: The answer directly addresses the query, providing a breakdown of Franklin Templeton's revenue streams. It is accurate, drawing information from the provided 10K filings. It could be slightly more complete by perhaps quantifying the relative importance of each revenue stream, if that information was available in the provided context (though it likely isn't). Citations are excellent, linking claims to specific pages in the 10K report.
# --------------------------------------------------
#
# ============================================================
# Query: Compare Franklin Templeton's 2023 performance vs previous years
# Method: hyde_retrieval
# Relevance: 5/5
# Accuracy: 5/5
# Completeness: 5/5
# Citation Quality: 5/5
# Reasoning: The response directly addresses the query by comparing Franklin Templeton's 2023 performance with previous years across various financial metrics. It uses information directly from Franklin Templeton's 2023 Annual Report (10K) to provide a detailed comparison. All statements are accurately sourced, and the answer provides a comprehensive overview of the company's financial performance.
# --------------------------------------------------
#
# ============================================================
# Query: What is the outlook for Franklin Templeton's growth strategy?
# Method: hyde_retrieval
# Relevance: 5/5
# Accuracy: 5/5
# Completeness: 4/5
# Citation Quality: 5/5
# Reasoning: The answer directly addresses the query about Franklin Templeton's growth strategy. It accurately reflects the information provided in the document. The answer covers multiple key aspects of their strategy, although further details from the 10K could potentially enhance completeness. The citations are clear and directly linked to specific pages in the source document.
# --------------------------------------------------
#
# ============================================================
# Query: What does NPV mean in finance?
# Method: direct_answer
# No retrieval performed - direct LLM answer
# --------------------------------------------------
#
# ============================================================
# Query: Franklin Templeton's biggest risks and challenges
# Method: hyde_retrieval
# Relevance: 5/5
# Accuracy: 5/5
# Completeness: 4/5
# Citation Quality: 5/5
# Reasoning: The response directly addresses the query about Franklin Templeton's risks and challenges, providing a clear and concise summary of key issues like market volatility, AUM fluctuations, fee pressure, and regulatory changes. The information is accurate and well-supported by citations to the Franklin 10K report. It could be improved by quantifying the potential impact of each risk where possible, but overall it's a strong and relevant answer.
# --------------------------------------------------
#
# ============================================================
# Query: How many employees does Franklin Templeton have worldwide?
# Method: simple_retrieval
# Relevance: 5/5
# Accuracy: 5/5
# Completeness: 5/5
# Citation Quality: 5/5
# Reasoning: The response accurately states that the provided documents do not contain the answer to the question, even though they mention employees. It also accurately lists the topics covered in the documents. The citations are relevant because they point to the specific documents used.
# --------------------------------------------------

# %% [markdown]
# ### 5.2 QAG

# %%
def generate_qa_pairs(n_pairs=5):
    """Generate Q&A pairs from random document chunks for evaluation"""

    # Get random documents
    import random
    all_docs = chroma_collection.get()['documents']
    random_docs = random.sample(all_docs, n_pairs)

    qa_pairs = []

    for doc in random_docs:
        prompt = f"""
        Based on this document chunk, generate 1 specific question that can be answered from the text:

        Document: {doc}

        Question (be specific and answerable from the text):
        """

        question = llm_groq.invoke(prompt).content.strip()

        # Get expected answer
        answer_prompt = f"Question: {question}\nDocument: {doc}\nAnswer:"
        expected_answer = llm_groq.invoke(answer_prompt).content.strip()

        qa_pairs.append({
            'question': question,
            'expected_answer': expected_answer,
            'source_doc': doc[:200] + "..."
        })

    return qa_pairs

def evaluate_with_qag():
    """Evaluate RAG system using generated Q&A pairs"""

    qa_pairs = generate_qa_pairs(5)
    total_score = 0

    print("=== QAG Evaluation ===")

    for i, qa in enumerate(qa_pairs):
        print(f"\nQ{i+1}: {qa['question']}")

        # Get RAG answer
        result = intelligent_retrieval_with_citations(qa['question'])
        rag_answer = result['answer']

        # Compare answers
        comparison_prompt = f"""
        Question: {qa['question']}
        Expected Answer: {qa['expected_answer']}
        RAG Answer: {rag_answer}

        How well does the RAG answer match the expected answer? Score 1-5:
        1=Completely different, 5=Very similar

        Score:
        """

        try:
            score = int(llm_groq.invoke(comparison_prompt).content.strip())
            score = max(1, min(5, score))
        except:
            score = 3

        total_score += score
        print(f"Score: {score}/5")
        print(f"RAG Answer: {rag_answer[:150]}...")

    avg_score = total_score / len(qa_pairs)
    print(f"\n=== QAG Results ===")
    print(f"Average Score: {avg_score:.2f}/5")

    return qa_pairs, avg_score

# %% [markdown]
# ### 5.3 Traditional Evaluations

# %%
def create_relevance_labels():
    """Create ground truth labels for traditional metrics"""

    test_queries = [
        "Franklin Templeton executives",
        "revenue and income",
        "investment strategies"
    ]

    labels = {}

    for query in test_queries:
        print(f"\n=== Labeling for: {query} ===")

        # Get top 10 results
        results = chroma_collection.query(
            query_texts=[query],
            n_results=10,
            include=['documents']
        )

        relevant_docs = []
        for i, doc in enumerate(results['documents'][0]):
            print(f"\nDoc {i}: {doc[:150]}...")
            relevance = input(f"Relevant to '{query}'? (y/n): ").lower().strip()
            if relevance == 'y':
                relevant_docs.append(i)

        labels[query] = relevant_docs
        print(f"Relevant docs for '{query}': {relevant_docs}")

    return labels

def calculate_traditional_metrics(labels):
    """Calculate Hit Rate, MRR, and Precision@K"""

    results = {}

    for query, relevant_indices in labels.items():
        # For this simple example, assume retrieved docs are in order 0,1,2,3,4...
        k_values = [1, 3, 5]

        # Hit Rate@K
        hit_rates = {}
        for k in k_values:
            top_k = list(range(k))
            hit = any(idx in relevant_indices for idx in top_k)
            hit_rates[k] = 1 if hit else 0

        # MRR (Mean Reciprocal Rank)
        reciprocal_rank = 0
        for rank, doc_idx in enumerate(range(10)):  # Check top 10
            if doc_idx in relevant_indices:
                reciprocal_rank = 1 / (rank + 1)
                break

        # Precision@K
        precisions = {}
        for k in k_values:
            top_k = list(range(k))
            relevant_in_top_k = sum(1 for idx in top_k if idx in relevant_indices)
            precisions[k] = relevant_in_top_k / k

        results[query] = {
            'hit_rates': hit_rates,
            'mrr': reciprocal_rank,
            'precisions': precisions
        }

    return results

def run_traditional_evaluation():
    """Run traditional IR metrics evaluation"""

    print("=== Traditional Metrics Evaluation ===")
    print("You'll need to manually label documents as relevant/not relevant")

    labels = create_relevance_labels()
    metrics = calculate_traditional_metrics(labels)

    print("\n=== Traditional Metrics Results ===")
    for query, scores in metrics.items():
        print(f"\nQuery: {query}")
        print(f"Hit@1: {scores['hit_rates'][1]}, Hit@3: {scores['hit_rates'][3]}, Hit@5: {scores['hit_rates'][5]}")
        print(f"MRR: {scores['mrr']:.3f}")
        print(f"Precision@1: {scores['precisions'][1]:.3f}, P@3: {scores['precisions'][3]:.3f}, P@5: {scores['precisions'][5]:.3f}")

    return metrics

# %%
print("=== Running QAG Evaluation ===")
qa_pairs, qag_score = evaluate_with_qag()
# Out:
# === Running QAG Evaluation ===
# === QAG Evaluation ===
#
# Q1: Who regulates companies, financial markets, and financial services in Australia?
# Score: 3/5
# RAG Answer: In Australia, the Australian Securities and Investments Commission (ASIC) regulates companies, financial markets, and financial services [1]. ASIC als...
#
# Q2: What was the total operating revenues for the third period listed in the document?
# Score: 3/5
# RAG Answer: The total operating revenues for the third period listed in the document, which corresponds to the fiscal year ended September 30, 2021, was $8,425.5 ...
#
# Q3: What was the total amount of operating revenues for the most recent year listed in the document?
# Score: 3/5
# RAG Answer: The total amount of operating revenues for the most recent year listed in the document, which is the fiscal year ended September 30, 2023, was $7,849....
#
# Q4: What is the primary composition of the Company's Cash and Cash Equivalents?
# Score: 3/5
# RAG Answer: The primary composition of the Company's Cash and Cash Equivalents consists of nonconsolidated sponsored money market funds and deposits with financia...
#
# Q5: What type of laws and regulations are a majority of the jurisdictions where the company operates covered by, according to the document?
# Score: 3/5
# RAG Answer: The laws and regulations that cover the jurisdictions where the company operates are extensive, complex, overlapping, and frequently changing [3]. The...
#
# === QAG Results ===
# Average Score: 3.00/5

# %%
def get_sample_ground_truth():
    """Pre-defined ground truth for teaching traditional metrics"""

    # Test these queries against your collection
    queries = ["Franklin Templeton executives", "revenue drivers", "investment management"]

    # Run each query to see results, then hardcode relevant indices
    ground_truth = {
        "Franklin Templeton executives": [0, 2, 4],  # Assume docs 0,2,4 mention executives
        "revenue drivers": [1, 3, 5, 7],             # Assume docs 1,3,5,7 discuss revenue
        "investment management": [0, 1, 6, 8, 9]     # Assume docs 0,1,6,8,9 cover investments
    }

    return ground_truth

def calculate_metrics_simple(query, relevant_docs, retrieved_docs_indices):
    """Calculate Hit@K, MRR, Precision@K for one query"""

    # Hit Rate@K
    hit_at_1 = 1 if retrieved_docs_indices[0] in relevant_docs else 0
    hit_at_3 = 1 if any(idx in relevant_docs for idx in retrieved_docs_indices[:3]) else 0
    hit_at_5 = 1 if any(idx in relevant_docs for idx in retrieved_docs_indices[:5]) else 0

    # MRR
    mrr = 0
    for rank, doc_idx in enumerate(retrieved_docs_indices):
        if doc_idx in relevant_docs:
            mrr = 1 / (rank + 1)
            break

    # Precision@K
    p_at_3 = sum(1 for idx in retrieved_docs_indices[:3] if idx in relevant_docs) / 3
    p_at_5 = sum(1 for idx in retrieved_docs_indices[:5] if idx in relevant_docs) / 5

    return {
        "hit_at_1": hit_at_1, "hit_at_3": hit_at_3, "hit_at_5": hit_at_5,
        "mrr": mrr, "precision_at_3": p_at_3, "precision_at_5": p_at_5
    }

def run_simple_traditional_eval():
    """Run traditional metrics with hardcoded ground truth"""

    ground_truth = get_sample_ground_truth()

    for query, relevant_docs in ground_truth.items():
        print(f"\nQuery: {query}")
        print(f"Ground truth relevant docs: {relevant_docs}")

        # Get actual retrieval results (assumes your retrieval returns doc indices)
        results = chroma_collection.query(query_texts=[query], n_results=5)
        retrieved_indices = list(range(5))  # This assumes docs 0,1,2,3,4 were retrieved

        metrics = calculate_metrics_simple(query, relevant_docs, retrieved_indices)

        print(f"Hit@1: {metrics['hit_at_1']}, Hit@3: {metrics['hit_at_3']}, Hit@5: {metrics['hit_at_5']}")
        print(f"MRR: {metrics['mrr']:.3f}")
        print(f"P@3: {metrics['precision_at_3']:.3f}, P@5: {metrics['precision_at_5']:.3f}")

# Run it
run_simple_traditional_eval()
# Out:
# Query: Franklin Templeton executives
# Ground truth relevant docs: [0, 2, 4]
# Hit@1: 1, Hit@3: 1, Hit@5: 1
# MRR: 1.000
# P@3: 0.667, P@5: 0.600
#
# Query: revenue drivers
# Ground truth relevant docs: [1, 3, 5, 7]
# Hit@1: 0, Hit@3: 1, Hit@5: 1
# MRR: 0.500
# P@3: 0.333, P@5: 0.400
#
# Query: investment management
# Ground truth relevant docs: [0, 1, 6, 8, 9]
# Hit@1: 1, Hit@3: 1, Hit@5: 1
# MRR: 1.000
# P@3: 0.667, P@5: 0.400

# %% [markdown]
# ## Step 6: Intelligent Ranking and Compression

# %%
from sentence_transformers import CrossEncoder
cross_encoder = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def compress_context(documents, query, max_length=500):
    """Compress documents to fit context window while preserving relevance"""
    compressed_docs = []
    for doc in documents:
        compression_prompt = f"""
        Compress this document to under {max_length} characters while keeping ALL information relevant to: "{query}"

        Document: {doc}

        Compressed version:
        """

        compressed = llm_gemini(compression_prompt)
        compressed_docs.append(compressed.strip())

    return compressed_docs

# %%
def rerank_with_cross_encoder(query, initial_k=20, final_k=5):
    results = chroma_collection.query(
        query_texts=[query],
        n_results=initial_k,
        include=['documents', 'metadatas']
    )

    pairs = [[query, doc] for doc in results['documents'][0]]
    scores = cross_encoder.predict(pairs)

    sorted_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:final_k]

    reranked_docs = [results['documents'][0][i] for i in sorted_indices]
    reranked_metadata = [results['metadatas'][0][i] for i in sorted_indices]

    return reranked_docs, reranked_metadata, [scores[i] for i in sorted_indices]


query = f"Who are the key executives of Franklin Templeton?"
top_docs = rerank_with_cross_encoder(query)
top_docs
# Out:
# (['Management Banking from 2006 to 2007.\nAlok Sethi\nAge 62\nExecutive Vice President and Head of Global Operations of Franklin since February 2023; formerly, Executive Vice \nPresident, Technology and Operations, of Franklin from October 2021 to February 2023; officer and/or director of various \ninvestment adviser, operations, and technology related subsidiaries of Franklin for more than the past five years, including \nas Senior Vice President of Franklin Advisers, Inc., Franklin Templeton Institutional, LLC and Templeton Investment \nCounsel, LLC since July 2014, and Vice President of Franklin Templeton Companies, LLC since June 2010.\nGwen L. Shaneyfelt\nAge 61\nChief Accounting Officer of Franklin since April 2019; officer and/or director of certain subsidiaries of Franklin, including \nas Vice President and Chief Financial Officer of Legg Mason, Inc., Director of ClearBridge Investments, LLC and',
#   'contribution where combined we will have \nover $100 billion in AUM. Furthermore, the \nacquisition is structured to maintain Franklin \nTempleton’s financial flexibility and promote Matthew Nicholls\nExecutive Vice President  \nChief Financial Officer \nChief Operating OfficerDiversification and discipline \nbenefit shareholders and clients\nour continuing investments in the business, \nwhile protecting our financial position in the \ncontext of challenging market conditions.\nGreat-West Lifeco will make an initial \nincremental long-term asset allocation  \nof $25 billion to our specialist investment \nmanager s and become a long-term \nshareholder in Franklin Resources.  \nThe agreement furthers our goal of growing \ninsur ance client assets and expands  \nthe existing relationship between Franklin \nTempleton and the Power group of companies \nin the key areas of retirement, asset \nmanagement and wealth management.\nAs market conditions continue to be \nvolatile, have your capital management',
#   'Manager of Royce & Associates GP, LLC since August 2020; as well as Director of Franklin Templeton Fund \nManagement Limited since May 2019, Manager of Franklin Templeton International Services S.à r.l. since November \n2013, and Senior Vice President of Franklin Templeton Companies, LLC since March 2011.\nAdam B. Spector\nAge 55 \nExecutive Vice President and Head of Global Distribution of Franklin since February 2023, responsible for global retail \nand institutional distribution, including marketing and product strategy, and Managing Partner of Brandywine Global \nInvestment Management, LLC since November 2014, responsible for the overall management of Brandywine including \ninfrastructure, legal and compliance, business strategy, and sales and client service; formerly, Executive Vice President of \nGlobal Advisory Services of Franklin from October 2020 to February 2023; Managing Director of Brandywine from 2012',
#   '6 FRANKLIN RESOURCES, INC. ANNUAL REPORT 2023from left to right: \nSelene Oh\nChief Communications Officer\nJennifer Ball\nChief Marketing Officer\nfrom left to right: \nAdam Petryk, CFA\nHead of Franklin Templeton \nInvestment Solutions\nBrett Goldstein, CFA\nCo-Chief  \nInvestment Officer\nPutnam Global Asset \nAllocation\nWylie Tollette, CFA\nChief Investment Officer\nFranklin Templeton  \nInvestment Solutions\nRobert Schoen\nCo-Chief  \nInvestment Officer\nPutnam Global Asset \nAllocationOver the past several years, we have focused on further diversifying our \nbusiness to build a more resilient organization able to withstand various \nmarket cycles, including volatile conditions such as in fiscal year 2023.  \nWe have expanded investment access and built upon our extensive range \nof capabilities, including investment insights, cutting-edge technology  \nand product inn ovation. Today, Franklin Templeton is well-positioned as  \na partner of choice by offering a full range of investment capabilities across',
#   '4 FRANKLIN RESOURCES, INC. ANNUAL REPORT 2023\nDirectors and executive officers\nAs of October 1, 2023\nour continuing investments in the business, \nwhile protecting our financial position in the \ncontext of challenging market conditions.\nGreat-West Lifeco will make an initial \nincremental long-term asset allocation  \nof $25 billion to our specialist investment \nmanager s and become a long-term \nshareholder in Franklin Resources.  \nThe agreement furthers our goal of growing \ninsur ance client assets and expands  \nthe existing relationship between Franklin \nTempleton and the Power group of companies \nin the key areas of retirement, asset \nmanagement and wealth management.\nAs market conditions continue to be \nvolatile, have your capital management \npriorities changed?\nCapital management is always a top priority. \nThis year, we returned $870 million to \nshareholders through dividends and share \nrepurchases, an increase of approximately 13% \nover the prior year, and funded the acquisition'],
#  [{'page': 22, 'source': 'Franklin 10K'},
#   {'page': 4, 'source': 'Franklin 10K'},
#   {'source': 'Franklin 10K', 'page': 22},
#   {'source': 'Franklin 10K', 'page': 5},
#   {'page': 4, 'source': 'Franklin 10K'}],
#  [np.float32(4.9282703),
#   np.float32(4.801686),
#   np.float32(4.393257),
#   np.float32(4.0346327),
#   np.float32(3.0880156)])

# %%
def rerank_and_compress(query, initial_k=20, final_k=5):
    """Combined reranking and compression"""

    # Step 1: Rerank
    reranked_docs, metadata, scores = rerank_with_cross_encoder(query, initial_k, final_k)

    # Step 2: Compress
    compressed_docs = compress_context(reranked_docs, query)

    print(f"Reranked from {initial_k} to {final_k} docs, then compressed")
    for i, (doc, score) in enumerate(zip(compressed_docs, scores)):
        print(f"Doc {i+1} (score: {score:.3f}): {doc[:100]}...")

    return compressed_docs, metadata, scores


rerank_and_compress("Key executives of Franklin Templeton")
# Out:
# Reranked from 20 to 5 docs, then compressed
# Doc 1 (score: 6.191): Franklin Templeton Key Executives:
#
# *   Alok Sethi, 62, EVP, Head of Global Operations (since Feb 20...
# Doc 2 (score: 6.046): Adam Spector, EVP, Head of Global Distribution since Feb 2023. Also manages Brandywine Global since ...
# Doc 3 (score: 5.418): Franklin Templeton key executives: Matthew Nicholls, Executive Vice President, CFO, COO....
# Doc 4 (score: 5.181): Franklin Templeton Key Executives: Selene Oh (CCO), Jennifer Ball (CMO), Adam Petryk (Head, FT Inves...
# Doc 5 (score: 3.859): Franklin Templeton key executives (Oct 1, 2023): Directors & executive officers....
# (['Franklin Templeton Key Executives:\n\n*   Alok Sethi, 62, EVP, Head of Global Operations (since Feb 2023).\n*   Gwen L. Shaneyfelt, 61, Chief Accounting Officer (since April 2019).',
#   'Adam Spector, EVP, Head of Global Distribution since Feb 2023. Also manages Brandywine Global since Nov 2014.',
#   'Franklin Templeton key executives: Matthew Nicholls, Executive Vice President, CFO, COO.',
#   'Franklin Templeton Key Executives: Selene Oh (CCO), Jennifer Ball (CMO), Adam Petryk (Head, FT Investment Solutions), Brett Goldstein (Co-CIO, Putnam), Wylie Tollette (CIO, FT Investment Solutions), Robert Schoen (Co-CIO, Putnam).',
#   'Franklin Templeton key executives (Oct 1, 2023): Directors & executive officers.'],
#  [{'page': 22, 'source': 'Franklin 10K'},
#   {'source': 'Franklin 10K', 'page': 22},
#   {'source': 'Franklin 10K', 'page': 4},
#   {'page': 5, 'source': 'Franklin 10K'},
#   {'page': 4, 'source': 'Franklin 10K'}],
#  [np.float32(6.1914296),
#   np.float32(6.0456767),
#   np.float32(5.4176426),
#   np.float32(5.1805034),
#   np.float32(3.8586898)])

# %%
def intelligent_retrieval_with_citations(query):
    """Enhanced retrieval with reranking, compression, and citations"""

    enhanced_queries = enhance_query(query)
    strategy = route_query(query)

    if strategy == "direct_answer":
        return {"answer": llm_gemini(query), "method": strategy}

    # Step 1: Initial retrieval with more candidates for reranking
    results = chroma_collection.query(
        query_texts=enhanced_queries,
        n_results=15,  # Get more for reranking
        include=['documents', 'metadatas']
    )

    # Step 2: Rerank with cross-encoder
    pairs = [[query, doc] for doc in results['documents'][0]]
    scores = cross_encoder.predict(pairs)
    sorted_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:5]

    reranked_docs = [results['documents'][0][i] for i in sorted_indices]
    reranked_metadata = [results['metadatas'][0][i] for i in sorted_indices]

    # Step 3: LLM-based compression
    compressed_docs = compress_context(reranked_docs, query, max_length=400)

    # Step 4: Generate answer with citations
    cited_answer = generate_answer_with_citations(query, compressed_docs, reranked_metadata)

    # Add references
    references = "\n\nReferences:\n"
    for i, meta in enumerate(reranked_metadata):
        references += f"[{i+1}] Franklin 10K, Page {meta['page']}\n"

    return {
        "answer": cited_answer + references,
        "method": f"{strategy}_with_reranking",
        "compression_used": True
    }

# %%
def intelligent_rag_with_metrics(query):
    result = intelligent_retrieval_with_citations("Key executives of Franklin Templeton")
    answer = result['answer']
    method = result['method']

    citations = len(re.findall(r'\[(\d+)\]', answer))

    # Count references at bottom
    references = len(re.findall(r'\[\d+\] Franklin', answer))

    print(f"Method: {method}")
    print(f"Answer length: {len(answer)} chars")
    print(f"Citations used: {citations}")
    print(f"Sources: {references} documents")
    print(f"Compression: {result.get('compression_used', False)}")
    print(word_wrap(f"Answer: {answer}..."))

intelligent_rag_with_metrics("Discuss about the key decision makers at Franklin Templeton")
# Out:
# Method: simple_retrieval_with_reranking
# Answer length: 730 chars
# Citations used: 10
# Sources: 5 documents
# Compression: True
# Answer: Key executives at Franklin Templeton include Alok Sethi (EVP, Head of Global Operations) [1], Gwen L. Shaneyfelt (Chief
# Accounting Officer) [1], Adam B. Spector (EVP, Head of Global Distribution) [2], and Matthew Nicholls (Executive Vice
# President, CFO, COO) [3]. Other key executives include Selene Oh (Chief Communications Officer), Jennifer Ball (Chief Marketing
# Officer), Adam Petryk (Head of Investment Solutions), Brett Goldstein & Robert Schoen (Co-Chief Investment Officers, Putnam
# Global Asset Allocation), and Wylie Tollette (Chief Investment Officer, Investment Solutions) [4].
#
#
# References:
# [1] Franklin
# 10K, Page 22
# [2] Franklin 10K, Page 22
# [3] Franklin 10K, Page 4
# [4] Franklin 10K, Page 5
# [5] Franklin 10K, Page 4
# ...
